# %% [markdown]
# # Plot y=x, y=x^2, y=x^3 with different format styles in a graph

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Plot bar chart like the following

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

# %% [markdown]
# # Plot pie chart like the following

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# Data to plot
languages = 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'
popuratity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

# %% [markdown]
# # Draw a scatter plot for three different groups camparing weights and heights

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np 
weight1=[67,57.2,59.6,59.64,55.8,61.2,60.45,61,56.23,56]
height1=[101.7,197.6,98.3,125.1,113.7,157.7,136,148.9,125.3,114.9] 
weight2=[61.9,64,62.1,64.2,62.3,65.4,62.4,61.4,62.5,63.6]
height2=[152.8,155.3,135.1,125.2,151.3,135,182.2,195.9,165.1,125.1] 
weight3=[68.2,67.2,68.4,68.7,71,71.3,70.8,70,71.1,71.7]
height3=[165.8,170.9,192.8,135.4,161.4,136.1,167.1,235.1,181.1,177.3]

# %% [markdown]
# # Plot the following stacked bar chart

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np 

countries = ['USA', 'GB', 'China', 'Russia', 'Germany']
bronzes = np.array([38, 17, 26, 19, 15])
silvers = np.array([37, 23, 18, 18, 10])
golds = np.array([46, 27, 26, 19, 17])


plt.xticks(ind, countries)
plt.ylabel("Medals")
plt.xlabel("Countries")
plt.title("2012 Olympics Top Scorers' Medals by Proportion")
plt.ylim=1.0

# rotate axis labels
plt.setp(plt.gca().get_xticklabels(), rotation=45, horizontalalignment='right')

plt.show()

# %% [markdown]
# # Step 1: Crawl stock web

# %%
# %matplotlib inline
import pandas as pd

# crawl ./dataset/wearn_stock_price/index.html (origin url: https://stock.wearn.com/cdata.asp?kind=2330 )
# Out:
#                     0       1       2       3       4      5
# 0   個股股價行情表﹝2330 台積電﹞     NaN     NaN     NaN     NaN    NaN
# 1                  日期     開盤價     最高價     最低價     收盤價    成交量
# 2           107/07/04  217.00  217.50  215.50  216.00  15181
# 3           107/07/03  215.50  218.00  213.50  214.50  28286
# 4           107/07/02  218.50  219.00  214.00  214.00  32399
# 5           107/06/29  212.00  217.00  212.00  216.50  34251
# 6           107/06/28  211.00  214.50  210.00  212.00  37892
# 7           107/06/27  216.00  216.00  212.50  213.00  39768
# 8           107/06/26  215.50  216.00  212.50  214.50  38359
# 9           107/06/25  220.00  220.50  218.00  218.00  44905
# 10          107/06/22  224.50  227.50  224.00  227.50  43230
# 11          107/06/21  227.50  228.00  226.00  226.50  31181
# 12          107/06/20  224.50  227.50  223.50  226.00  40683
# 13          107/06/19  225.50  226.00  224.00  225.00  56777
# ...

# %% [markdown]
# # Step 2: Remove first two row and set new column name

# %%
df.columns = ['time', 'open', 'high', 'low', 'close', 'volume']
# Out:
#         time    open    high     low   close volume
# 0  107/07/04  217.00  217.50  215.50  216.00  15181
# 1  107/07/03  215.50  218.00  213.50  214.50  28286
# 2  107/07/02  218.50  219.00  214.00  214.00  32399
# 3  107/06/29  212.00  217.00  212.00  216.50  34251
# 4  107/06/28  211.00  214.50  210.00  212.00  37892

# %% [markdown]
# # Step 3: Change dataframe to time series

# %%
# Out:
#               open    high     low   close volume
# new_time
# 2018-07-04  217.00  217.50  215.50  216.00  15181
# 2018-07-03  215.50  218.00  213.50  214.50  28286
# 2018-07-02  218.50  219.00  214.00  214.00  32399
# 2018-06-29  212.00  217.00  212.00  216.50  34251
# 2018-06-28  211.00  214.50  210.00  212.00  37892

# %% [markdown]
# # Step 4: Change stock price to numerical
# ## hint: use df[index_name].astype('float64')

# %%
df.dtypes
# Out:
# open      object
# high      object
# low       object
# close     object
# volume    object
# dtype: object

# %%
# Out:
# open      float64
# high      float64
# low       float64
# close     float64
# volume    float64
# dtype: object

# %% [markdown]
# # Step 5: Plot time versus close price
